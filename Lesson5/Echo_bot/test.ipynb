# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
def fib(n):
    if n <= 1:
        return 1
    else:
        return fib(n-1) + fib(n-2)
    
print(fib(7))
# Out:
# 21

# %%
import math
print(fib(7))
# Out:
# 21

# %%
import cmath
def csolv(a,b,c):
    d = b**2 - 4*a*c
    
    x1 = (-b + cmath.sqrt(d)) / (2 * a)
    x2 = (-b - cmath.sqrt(d)) / (2 * a)
    return (x1, x2)
   

print(csolv(1, 2, 3))
# Out:
# ((-1+1.4142135623730951j), (-1-1.4142135623730951j))

# %%
import cmath
def csolv(a,b,c):
    d = b**2 - 4*a*c
    
    x1 = (-b + cmath.sqrt(d)) / (2 * a)
    x2 = (-b - cmath.sqrt(d)) / (2 * a)
    return (x1, x2)
   

print(csolv(1, 2, 3))
# Out:
# ((-1+1.4142135623730951j), (-1-1.4142135623730951j))

# %%
import scipy.optimize

def func(d):
    a,b,c = d
    f1 = a * (31) ** 2 + b * 31 + c - 19310
    f2 = a * (51) ** 2 + b * 51 + c - 52150
    f3 = a * (61) ** 2 + b * 61 + c - 74570
    return (f1,f2,f3)

 #Найдем решение f(a,b,c) = 0

optobj = scipy.optimize.root(func, (5,5,5))

if optobj.success:
    print(" [a,b,c] = ", optobj.x)
# Out:
#  [a,b,c] =  [20.  2. 28.]

# %%
x1 = 48; x2 = 54
f1 = 20*x1**2 + 2*x1 + 28
f2 = 20*x2**2 + 2*x2 + 28
print("f(48 кв.м.) = ",f1, "  f(54 кв.м.) = ",f2)
# Out:
# f(48 кв.м.) =  46204   f(54 кв.м.) =  58456

# %%
import sympy as sp
from sympy.plotting import plot 
x = sp.Symbol('x')
f = 20*x**2 + 2*x + 28
graph = sp.plot(f,(x,0,100),line_color='red',title="График роста стоимости квартиры от метража",xlabel="Метраж (кв.м)",ylabel="Цена")

# %%
import sympy as sp
from sympy import cos, sin
x = sp.Symbol('x')
expr =x-12*x**4*sin(cos(x))-18*x**3+5*x**2 + 10*x - 30
expr
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 11*x - 30

# %%
graph = sp.plot(expr)

# %%
expr_solveset = sp.solveset(expr)
expr_solveset
# Out:
# ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 11*x - 30, 0), Complexes)

# %%
print(expr)
expr_diff = sp.diff(expr)
#expr_diff
print(expr_diff)

sp.plot(expr)
sp.plot(expr_diff)
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 11*x - 30
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 11
