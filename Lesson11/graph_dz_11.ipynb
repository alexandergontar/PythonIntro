# %%
from sympy import symbols,sin,cos
from sympy.plotting import plot,plot3d


x = symbols('x')
#p1 = plot3d(x-12*x**4*sin(cos(x))-18*x**3+5*x**2 + 10*x - 30,line_color = "purple")
p1 = plot(x-12*x**4*sin(cos(x))-18*x**3+5*x**2 + 10*x - 30,line_color = "purple")
p1.show()
